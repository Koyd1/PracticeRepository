# %%
# %%bash
# git
# Out:
# usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#            [-p | --paginate | -P | --no-pager] [--no-replace-objects] [--bare]
#            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#            [--super-prefix=<path>] [--config-env=<name>=<envvar>]
#            <command> [<args>]
#
# These are common Git commands used in various situations:
#
# start a working area (see also: git help tutorial)
#    clone     Clone a repository into a new directory
#    init      Create an empty Git repository or reinitialize an existing one
#
# work on the current change (see also: git help everyday)
#    add       Add file contents to the index
#    mv        Move or rename a file, a directory, or a symlink
#    restore   Restore working tree files
#    rm        Remove files from the working tree and from the index
#
# examine the history and state (see also: git help revisions)
# ...

# %%
# %%bash
# rm -r sample_data

# %%
# %%bash
# cat > .gitignore
# .*
# .gitignore

# %%
# %%bash
# git config --global user.email "log.koyd@gmail.com"
# git config --global user.name "Alexandr Moroz"

# %%
# %%bash
# git init
# Out:
# Initialized empty Git repository in /content/.git/
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>

# %%
# %%bash
# ls -a
# Out:
# .
# ..
# .config
# .git
# .gitignore

# %%
# %%bash
# cat > textFile.txt
# This is a text file.
# It has the .fasta extension.

# %%
# %%bash
# git add .

# %%
# %%bash
# git diff --name-only --cached
# Out:
# textFile.txt

# %%
# %%bash
# git commit -m textFile.txt
# Out:
# [master (root-commit) 04bd2b9] textFile.txt
#  1 file changed, 2 insertions(+)
#  create mode 100644 textFile.txt

# %%
# %%bash
# cat > textFile.txt
# This is a text file.
# It has the .txt extension.

# %%
# %%bash
# git add -A
# git commit -m "Fixed the extension error in textFile.txt."
# Out:
# [master 8d539b2] Fixed the extension error in textFile.txt.
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# %%bash
# git remote add origin git@github.com:Koyd1/practice.git
# git branch -M main
# git push -u origin main

# %%
# %%bash
# ssh-keygen -t ed25519 -C 'log.koyd@gmail.com' -f ~/.ssh/id_ed25519 -P ''
# cat > ~/.ssh/config
# Host *
#   AddKeysToAgent yes
#   IdentityFile ~/.ssh/id_ed25519
# Out:
# Generating public/private ed25519 key pair.
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:6L61+fDamah3vZxzysUZRzqQIN/mufSg538VmAQhOZ8 log.koyd@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# |        ..ooo    |
# |         =.o o   |
# |          + B o .|
# |       .   E = + |
# |      . S   = + o|
# |     .     o = =.|
# |      . o ..o = .|
# |     . ..B.Boo. .|
# |      ++=+* B*.. |
# +----[SHA256]-----+
# Created directory '/root/.ssh'.

# %%
# %%bash
# eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_ed25519
# Out:
# Agent pid 4230
# Identity added: /root/.ssh/id_ed25519 (log.koyd@gmail.com)

# %%
# %%bash
# cat ~/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIAnIpEqnc2SjpVmpBRPx1FMomHZFfYejyagYDwbURQuB log.koyd@gmail.com

# %%
# %%bash
# ssh -o "StrictHostKeyChecking no" -T git@github.com
# Out:
# Hi Koyd1! You've successfully authenticated, but GitHub does not provide shell access.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-24-092455711042> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'ssh -o "StrictHostKeyChecking no" -T git@github.com\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# ...

# %%
# %%bash
# git branch -M main
# git push -u origin main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# To github.com:Koyd1/practice.git
#  * [new branch]      main -> main

# %%
# %%bash
# mkdir textFiles
# mv textFile.txt textFiles/textFile.txt

# %%
# %%bash
# git add -A
# git diff --name-only --cached
# Out:
# textFiles/textFile.txt

# %%
# %%bash
# git commit -m "Created a directory for the text file."
# Out:
# [main d312d46] Created a directory for the text file.
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  rename textFile.txt => textFiles/textFile.txt (100%)

# %%
# %%bash
# git push
# Out:
# To github.com:Koyd1/practice.git
#    8d539b2..d312d46  main -> main

# %%
# %%bash
# git clone https://github.com/mwaskom/seaborn-data.git
# Out:
# Cloning into 'seaborn-data'...

# %% [markdown]
# ---
# # **Lab Assignment**
#
# ---

# %%
# %%bash
# rm -r sample_data
# mkdir practiceRepository
# cd practiceRepository
# mkdir summarydata figure notebook
# touch README.txt

# %%
# %%bash
# cd /content/practiceRepository/summarydata
# touch README.txt
# wget -nv -O titanic.csv 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
# Out:
# bash: line 1: cd: content/practiceRepository/summarydata: No such file or directory
# 2024-06-28 15:00:56 URL:https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv [57018/57018] -> "titanic.csv" [1]

# %%
# %%bash
# cd /content/practiceRepository/notebook/
# touch README.txt
# wget -nv -O USMFLab6.ipynb 'https://drive.google.com/file/d/16jFHKGdMPPJNRJHgldf57kxphdhazlfv/view?usp=sharing'
# Out:
# 2024-06-28 15:02:25 URL:https://drive.google.com/file/d/16jFHKGdMPPJNRJHgldf57kxphdhazlfv/view?usp=sharing [92393] -> "USMFLab6.ipynb" [1]

# %%
# %%bash
# cd /content/practiceRepository/figure/
# touch README.txt
# wget -nv -O Figure1.png 'https://drive.google.com/uc?export=download&id=16ILHoAgv97bT8-N7_ilCOfPufwdUd3kg'
# wget -nv -O Figure2a.png 'https://drive.google.com/uc?export=download&id=1B9i4-hrZBitChHSVg_ObMpqO2zWjMVga'
# wget -nv -O Figure2b.png 'https://drive.google.com/uc?export=download&id=15zavQkX-coGdHQ4dejqYUdHaDXWVE3yB'
# wget -nv -O Figure3.png 'https://drive.google.com/uc?export=download&id=1I3_1YYvzBtg_SvT0DZ12oNXmK06UT5yM'
# wget -nv -O Figure4.png 'https://drive.google.com/uc?export=download&id=1TRMgeR3p9ghxXTK5xpkFbnSjNnw1H2X5'
# Out:
# 2024-06-28 15:07:52 URL:https://drive.usercontent.google.com/download?id=16ILHoAgv97bT8-N7_ilCOfPufwdUd3kg&export=download [23952/23952] -> "Figure1.png" [1]
# 2024-06-28 15:07:53 URL:https://drive.usercontent.google.com/download?id=1B9i4-hrZBitChHSVg_ObMpqO2zWjMVga&export=download [67838/67838] -> "Figure2a.png" [1]
# 2024-06-28 15:07:53 URL:https://drive.usercontent.google.com/download?id=15zavQkX-coGdHQ4dejqYUdHaDXWVE3yB&export=download [42184/42184] -> "Figure2b.png" [1]
# 2024-06-28 15:07:53 URL:https://drive.usercontent.google.com/download?id=1I3_1YYvzBtg_SvT0DZ12oNXmK06UT5yM&export=download [50787/50787] -> "Figure3.png" [1]
# 2024-06-28 15:07:54 URL:https://drive.usercontent.google.com/download?id=1TRMgeR3p9ghxXTK5xpkFbnSjNnw1H2X5&export=download [35948/35948] -> "Figure4.png" [1]

# %%
# %%bash
# ls -A
# Out:
# .config
# .git
# .gitignore
# .ipynb_checkpoints
# practiceRepository

# %%
# %%bash
# git add -A
# git commit -m "Lab6"
# Out:
# [main 55a3233] Lab6
#  12 files changed, 1025 insertions(+), 2 deletions(-)
#  create mode 100644 practiceRepository/README.txt
#  create mode 100644 practiceRepository/figure/Figure1.png
#  create mode 100644 practiceRepository/figure/Figure2a.png
#  create mode 100644 practiceRepository/figure/Figure2b.png
#  create mode 100644 practiceRepository/figure/Figure3.png
#  create mode 100644 practiceRepository/figure/Figure4.png
#  create mode 100644 practiceRepository/figure/README.txt
#  create mode 100644 practiceRepository/notebook/README.txt
#  create mode 100644 practiceRepository/notebook/USMFLab6.ipynb
#  create mode 100644 practiceRepository/summarydata/README.tet
#  create mode 100644 practiceRepository/summarydata/titanic.csv
#  delete mode 100644 textFiles/textFile.txt

# %%
# %%bash
# git push
# Out:
# To github.com:Koyd1/practice.git
#    d312d46..55a3233  main -> main

# %%
# %%bash
# cd /content/practiceRepository/notebook/
# wget -nv -O Lab1.ipynb 'https://colab.research.google.com/drive/1VT5iAGLBfeHmj8havnBXMN7hfODz-Lab?usp=drive_link'
# wget -nv -O Lab2.ipynb 'https://colab.research.google.com/drive/1Dt-j3_-RIsEM043yWVRnp2Mp3ECzyIGo?usp=drive_link'
# wget -nv -O Lab3.ipynb 'https://colab.research.google.com/drive/1hTYybha3LdAWtDREwcnQC2XIjkEY8Zh9?usp=drive_link'
# wget -nv -O Lab4.ipynb 'https://colab.research.google.com/drive/1-2KCzqDt6b9XW1hh0cSKCUZMJyvpep2q?usp=drive_link'
# wget -nv -O Lab5.ipynb 'https://colab.research.google.com/drive/1-2KCzqDt6b9XW1hh0cSKCUZMJyvpep2q?usp=drive_link'
# wget -nv -O Lab6.ipynb 'https://colab.research.google.com/drive/1en5NAeYFpKfhFMzd2uhMVTcCmhssKItx?usp=drive_link'
# Out:
# 2024-06-28 15:29:13 URL:https://colab.research.google.com/drive/1VT5iAGLBfeHmj8havnBXMN7hfODz-Lab?usp=drive_link [91134] -> "Lab1.ipynb" [1]
# 2024-06-28 15:29:13 URL:https://colab.research.google.com/drive/1Dt-j3_-RIsEM043yWVRnp2Mp3ECzyIGo?usp=drive_link [91122] -> "Lab2.ipynb" [1]
# 2024-06-28 15:29:13 URL:https://colab.research.google.com/drive/1hTYybha3LdAWtDREwcnQC2XIjkEY8Zh9?usp=drive_link [91117] -> "Lab3.ipynb" [1]
# 2024-06-28 15:29:13 URL:https://colab.research.google.com/drive/1-2KCzqDt6b9XW1hh0cSKCUZMJyvpep2q?usp=drive_link [91119] -> "Lab4.ipynb" [1]
# 2024-06-28 15:29:14 URL:https://colab.research.google.com/drive/1-2KCzqDt6b9XW1hh0cSKCUZMJyvpep2q?usp=drive_link [91128] -> "Lab5.ipynb" [1]
# 2024-06-28 15:29:14 URL:https://colab.research.google.com/drive/1en5NAeYFpKfhFMzd2uhMVTcCmhssKItx?usp=drive_link [91131] -> "Lab6.ipynb" [1]

# %%
# %%bash
# git add -A
# git commit -m "Labs"
# git push
# Out:
# [main d01da22] Labs
#  16 files changed, 0 insertions(+), 0 deletions(-)
#  rename practiceRepository/README.txt => README.txt (100%)
#  rename {practiceRepository/figure => figure}/Figure1.png (100%)
#  rename {practiceRepository/figure => figure}/Figure2a.png (100%)
#  rename {practiceRepository/figure => figure}/Figure2b.png (100%)
#  rename {practiceRepository/figure => figure}/Figure3.png (100%)
#  rename {practiceRepository/figure => figure}/Figure4.png (100%)
#  rename {practiceRepository/figure => figure}/README.txt (100%)
#  rename {practiceRepository/notebook => notebook}/Lab1.ipynb (100%)
#  rename {practiceRepository/notebook => notebook}/Lab2.ipynb (100%)
#  rename {practiceRepository/notebook => notebook}/Lab3.ipynb (100%)
#  rename {practiceRepository/notebook => notebook}/Lab4.ipynb (100%)
#  rename {practiceRepository/notebook => notebook}/Lab5.ipynb (100%)
#  rename {practiceRepository/notebook => notebook}/Lab6.ipynb (100%)
# ...
