# %% [markdown]
# Rename sample_data to Repository

# %%
# %%bash
# mv sample_data Repository

# %% [markdown]
# Create - 4 sub dir and one folder "README"

# %%
# %%bash
# cd Repository
# rm *
# touch README
# mkdir summarydata notebook figure multipanel
# ls
# Out:
# figure
# multipanel
# notebook
# README
# summarydata

# %% [markdown]
# Creating child files for sub dir

# %%
# %%bash
# cd Repository/summarydata/
# touch README Figure_1adata.csv Figure_1bdata.csv Figure_2adata.csv Figure_2bdata.csv Figure_2cdata.csv
# ls
# cd ../notebook
# touch README Figure1.ipynb Figure2.ipynb
# ls
# cd ../figure
# touch README Figure1a.pdf Figure2a.pdf Figure2a.pdf Figure2b.pdf Figure2c.pdf
# ls
# cd ../multipanel
# touch README Figure1.ai Figure2.ai
# ls
# Out:
# Figure_1adata.csv
# Figure_1bdata.csv
# Figure_2adata.csv
# Figure_2bdata.csv
# Figure_2cdata.csv
# README
# Figure1.ipynb
# Figure2.ipynb
# README
# Figure1a.pdf
# Figure2a.pdf
# Figure2b.pdf
# Figure2c.pdf
# README
# Figure1.ai
# Figure2.ai
# README
