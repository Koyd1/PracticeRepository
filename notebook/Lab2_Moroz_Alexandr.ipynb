# %% [markdown]
# ---
# Download a file from a direct-download link

# %%
# %%bash
# wget -nv -O IGHJ_Mouse.fa 'https://drive.google.com/uc?export=download&id=19OjK8m9M9WwUZpB-5FLSu7RWeQhRbYKO'
# wget -nv -O IGHJ_Human.fa 'https://drive.google.com/uc?export=download&id=1kUzbiYfBOYQDXUaUzJ4NEGJN9ysPulBz'
# wget -nv -O IGHJ_Zebrafish.fa 'https://drive.google.com/uc?export=download&id=1m0VB08CBfl6GZ9rfCtmDyh6PI7elHcak'
# Out:
# 2024-06-26 09:40:56 URL:https://drive.usercontent.google.com/download?id=19OjK8m9M9WwUZpB-5FLSu7RWeQhRbYKO&export=download [1178/1178] -> "IGHJ_Mouse.fa" [1]
# 2024-06-26 09:40:57 URL:https://drive.usercontent.google.com/download?id=1kUzbiYfBOYQDXUaUzJ4NEGJN9ysPulBz&export=download [2639/2639] -> "IGHJ_Human.fa" [1]
# 2024-06-26 09:40:57 URL:https://drive.usercontent.google.com/download?id=1m0VB08CBfl6GZ9rfCtmDyh6PI7elHcak&export=download [1034/1034] -> "IGHJ_Zebrafish.fa" [1]

# %% [markdown]
# Text below the cat > line was saved to the headerExtractor, all lines in *.fa files string at "<"

# %%
# %%bash
# rm -r sample_data
# cat > headerExtractor
# #!/bin/bash
# grep "^>" *.fa > headers.txt

# %%
# %%bash
# chmod u+x headerExtractor

# %% [markdown]
# Now script is executable

# %%
# %%bash
# ./headerExtractor

# %% [markdown]
# ---

# %%
# %%bash
# cat > seqMeasurer
# #!/bin/bash
# grep "^>" *Human.fa > lengths.txt
# grep -v -h "^>" *Human.fa | tr -d '\n'|wc -m >> lengths.txt
# grep "^>" *Mouse.fa>> lengths.txt
# grep -v -h "^>" *Mouse.fa | tr -d '\n'|wc -m >> lengths.txt
# grep "^>" *Zebrafish.fa >> lengths.txt
# grep -v -h "^>" *Zebrafish.fa | tr -d '\n'|wc -m >> lengths.txt

# %%
# %%bash
# chmod u+x seqMeasurer

# %%
# %%bash
# ./seqMeasurer

# %% [markdown]
# ---
