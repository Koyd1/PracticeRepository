# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
lab2_data = sns.load_dataset('titanic')
lab2_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(data=lab2_data, x='class', y='survived', hue='class')
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(data=lab2_data, x='class', y='survived', hue='who')
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
lab2_data.loc[(lab2_data['who'] == 'child') & (lab2_data['sex'] == 'male'), 'who'] = 'boy'
lab2_data.loc[(lab2_data['who'] == 'child') & (lab2_data['sex'] == 'female'), 'who'] = 'girl'
sns.barplot(data=lab2_data, x='class', y='survived', hue='who')
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90)
# Out:
# <ipython-input-46-6fc1f79693e4>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90)
# <Axes: xlabel='class', ylabel='survived'>

# %%
lab2_data_sorted = lab2_data.sort_values(by='age', ascending=False)
sns.barplot(data=lab2_data_sorted, x='survived', y='age', hue='who')
plt.show()

# %%
lab2_data.loc[(lab2_data['survived'] == 0), 'survived_str'] = 'no'
lab2_data.loc[(lab2_data['survived'] == 1),  'survived_str'] = 'yes'
lab2_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
sns.barplot(data=lab2_data, x='survived_str', y='age', hue='who')
plt.show()

# %%
sns.barplot(data=lab2_data, x='survived_str', y='age', hue='who', estimator = np.median , ci='sd', capsize=0.05)
# Out:
# <ipython-input-10-8cb4b48ac7d3>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=lab2_data, x='survived_str', y='age', hue='who', estimator = np.median , ci='sd', capsize=0.05)
# <Axes: xlabel='survived_str', ylabel='age'>

# %%
sns.boxplot(data=lab2_data, x='survived_str', y='age', hue='who', fliersize=5)
# Out:
# <Axes: xlabel='survived_str', ylabel='age'>

# %%
flierprops = dict(marker='d', markerfacecolor='b', markersize=6)
sns.boxplot(data=lab2_data, x='survived_str', y='age', hue='who', fliersize=5, flierprops=flierprops)
# Out:
# <Axes: xlabel='survived_str', ylabel='age'>

# %%
sns.stripplot(data=lab2_data, x='survived_str', y='age', hue='who', jitter=0.3, alpha=0.5, dodge='true')
# Out:
# <Axes: xlabel='survived_str', ylabel='age'>

# %% [markdown]
# ---
#
# ## Part 2
# ###1
#
# ---

# %%
lab3_data = sns.load_dataset('titanic')
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'male'), 'who'] = 'boy'
lab3_data.loc[(lab3_data['who'] == 'child') & (lab3_data['sex'] == 'female'), 'who'] = 'girl'
lab3_data.loc[lab3_data['survived'] == 0, 'survived_str'] = 'no'
lab3_data.loc[lab3_data['survived'] == 1,  'survived_str'] = 'yes'

# %%
sns.set_style("white")
sns.set_context("paper")

# %%
colors = {'man':'blue','woman':'tab:orange','boy':'cornflowerblue','girl':'sandybrown'}

# %%
sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90, palette = colors)
# Out:
# <ipython-input-115-309da7ce210e>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab2_data, x='class', y='survived', hue='who', capsize=0.05, ci=90, palette = colors)
# <Axes: xlabel='class', ylabel='survived'>

# %%
lab2_data_filtered = lab2_data[lab2_data['class'] != 'Second']
lab2_data_sorted = lab2_data_filtered.sort_values(by='age', ascending=False)
x_order = ['First', 'Third']

# %%
sns.barplot(data=lab2_data_sorted, x='class', y='survived', hue='who', palette=colors, capsize=0.05, ci=90,order=x_order)
plt.show()
# Out:
# <ipython-input-122-5a6cb85742a2>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   sns.barplot(data=lab2_data_sorted, x='class', y='survived', hue='who', palette=colors, capsize=0.05, ci=90,order=x_order)

# %%
axes = sns.barplot(data=lab2_data_sorted, x='class', y='survived', hue='who', palette=colors, capsize=0.05, ci=90,order=x_order)
axes.set_xlabel('Boarding Class')
axes.set_ylabel('Mean Survival Rate')
plt.show()
# Out:
# <ipython-input-130-e4b396210226>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   axes = sns.barplot(data=lab2_data_sorted, x='class', y='survived', hue='who', palette=colors, capsize=0.05, ci=90,order=x_order)

# %%
axes = sns.barplot(data=lab2_data_sorted, x='class', y='survived', hue='who', palette=colors, capsize=0.05, ci=90,order=x_order)
axes.set_xlabel('Boarding Class')
axes.set_ylabel('Mean Survival Rate')
sns.despine()
plt.show()
# Out:
# <ipython-input-131-d4a451df8219>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 90)` for the same effect.
#
#   axes = sns.barplot(data=lab2_data_sorted, x='class', y='survived', hue='who', palette=colors, capsize=0.05, ci=90,order=x_order)

# %% [markdown]
# ---
#
# ###2
#
# ---

# %%
sns.boxplot(data=lab2_data, x='survived_str', y='age', hue='who', fliersize=5,boxprops={'edgecolor':'black','facecolor':(1,1,1,1)})
# Out:
# <Axes: xlabel='survived_str', ylabel='age'>

# %%
axes2 = sns.boxplot(data=lab2_data, zorder = 0 ,x='survived_str', y='age', hue='who', fliersize=5,boxprops={'edgecolor':'black','facecolor':(1,1,1,1)})
axes2 = sns.stripplot(data=lab2_data,zorder = 5 ,x='survived_str', y='age', hue='who', jitter=0.3, alpha=0.5, dodge='true', palette = colors)
handles, labels = axes2.get_legend_handles_labels()
axes2.set_xlabel('Survived')
axes2.set_ylabel('Age')
plt.legend(handles[4:8], labels[4:8], title='who')

# %% [markdown]
# ---
#
# ### 3
#
# ---

# %%
axes3 = sns.violinplot(data=lab2_data, x='survived_str', y='age', hue='who',palette=colors)
axes3.set_xlabel('Survived')
axes3.set_ylabel('Age')
sns.despine()

# %% [markdown]
# ---
#
# ###4
#
# ---

# %%
axes4 = sns.scatterplot(data=lab2_data, x='age', y='fare',hue='class')
axes4.set_xlabel('Fare')
axes4.set_ylabel('Age')
sns.despine()

# %% [markdown]
# ---
#
# ###5
#
# ---

# %%
lab3_data_subset=lab3_data[['class','who','fare']]
lab3_data_subset=lab3_data_subset.dropna(how='any')
lab3_data_subsetAverage=lab3_data_subset.groupby(['class','who']).mean()
lab3_data_subsetAverage=lab3_data_subsetAverage.reset_index()
lab3_data_subsetAverage.head()
# Out:
#     class    who        fare
# 0   First    boy  117.802767
# 1   First   girl  160.962500
# 2   First    man   65.951086
# 3   First  woman  104.317995
# 4  Second    boy   27.306022

# %%
lab3_data_subset = lab3_data[['class', 'who', 'fare']]
lab3_data_subset = lab3_data_subset.dropna(how='any')
lab3_data_subsetAverage = lab3_data_subset.groupby(['class', 'who']).mean()
lab3_data_subsetAverage = lab3_data_subsetAverage.reset_index()

matrix_data = lab3_data_subsetAverage.pivot(index='class', columns='who', values='fare')
axes5 = sns.heatmap(data=matrix_data, annot=True, fmt='.2f', cmap='coolwarm')

for text in axes5.texts:
    text.set_text('£' + text.get_text())
    axes5.set(xlabel='Demographic', ylabel='Boarding Class', xticklabels=['boy', 'girl', 'man', 'woman'])
plt.show()
